# %%
# =====================================================================
# GHOSTNET GROCERY STORE CLASSIFICATION - K-FOLD 5 CROSS VALIDATION
# TANPA AUGMENTASI DATA
# OPTIMIZER: SGD WITH MOMENTUM
# =====================================================================

# =====================================================================
# 1. SETUP AND INSTALLATIONS
# =====================================================================

import os
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
from pathlib import Path
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, Subset
from torchvision import transforms
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix
from tqdm.auto import tqdm
import warnings
import random
warnings.filterwarnings('ignore')

# Install timm for GhostNet
# !pip install timm -q

import timm

# Set random seeds for reproducibility
torch.manual_seed(42)
np.random.seed(42)
random.seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)
    torch.backends.cudnn.deterministic = True

# Set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")

# =====================================================================
# 2. MOUNT GOOGLE DRIVE
# =====================================================================

from google.colab import drive
drive.mount('/content/drive')

# Update this path to your dataset location in Google Drive
DATASET_PATH = '/content/drive/MyDrive/GroceryStoreDataset/dataset'

# =====================================================================
# 3. DATASET CLASS - TRAIN
# =====================================================================

class GroceryStoreDataset(Dataset):

    def __init__(self, root_dir, splits=['train'], transform=None):
        self.root_dir = Path(root_dir)
        self.splits = splits if isinstance(splits, list) else [splits]
        self.transform = transform

        # Collect all images and labels
        self.images = []
        self.labels = []
        self.class_names = []

        print(f"\nLoading dataset from: {', '.join(self.splits)}")

        # Collect all leaf folders from all splits
        all_leaf_folders = []
        for split in self.splits:
            data_dir = self.root_dir / split
            if not data_dir.exists():
                print(f"  ⚠️  Warning: {split} folder not found, skipping...")
                continue

            for root, dirs, files in os.walk(data_dir):
                image_files = [f for f in files if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
                if image_files and not dirs:
                    all_leaf_folders.append(Path(root))

        # Sort and get unique class names
        all_leaf_folders = sorted(list(set(all_leaf_folders)))

        # Extract class names (leaf folder names)
        class_name_set = set()
        for folder in all_leaf_folders:
            class_name_set.add(folder.name)

        self.class_names = sorted(list(class_name_set))
        self.class_to_idx = {cls_name: idx for idx, cls_name in enumerate(self.class_names)}

        print(f"  ✓ Found {len(self.class_names)} unique classes")

        # Collect all images
        for folder in all_leaf_folders:
            class_name = folder.name
            class_idx = self.class_to_idx[class_name]

            for img_file in folder.glob('*.jpg'):
                self.images.append(str(img_file))
                self.labels.append(class_idx)
            for img_file in folder.glob('*.png'):
                self.images.append(str(img_file))
                self.labels.append(class_idx)

        if len(self.images) > 0:
            unique, counts = np.unique(self.labels, return_counts=True)
            print(f"  ✓ Images per class: min={counts.min()}, max={counts.max()}, avg={counts.mean():.1f}")

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        label = self.labels[idx]

        try:
            image = Image.open(img_path).convert('RGB')
        except Exception as e:
            print(f"Error loading image {img_path}: {e}")
            image = Image.new('RGB', (224, 224), (0, 0, 0))

        if self.transform:
            image = self.transform(image)

        return image, label

# =====================================================================
# 4. DATA TRANSFORMATIONS - TANPA AUGMENTASI
# =====================================================================

# Transform yang sama untuk train, validation, dan test (TANPA AUGMENTASI)
standard_transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                       std=[0.229, 0.224, 0.225])
])

print("\n⚠️  DATA AUGMENTATION: DISABLED")
print("✓ Using only basic transformations (Resize + CenterCrop + Normalize)")

# =====================================================================
# 5. LOAD DATASETS
# =====================================================================

print("\n" + "="*60)
print("LOADING DATASETS")
print("="*60)

# Load train+val combined
full_trainval_dataset = GroceryStoreDataset(
    root_dir=DATASET_PATH,
    splits=['train'],
    transform=standard_transform
)

# Load test dataset separately
test_dataset = GroceryStoreDataset(
    root_dir=DATASET_PATH,
    splits=['test'],
    transform=standard_transform
)

NUM_CLASSES = len(full_trainval_dataset.class_names)

print(f"\n✓ Total classes: {NUM_CLASSES}")

# Create test loader (same for all folds)
test_loader = DataLoader(
    test_dataset,
    batch_size=64,
    shuffle=False,
    num_workers=0,
    pin_memory=True if torch.cuda.is_available() else False
)

# =====================================================================
# 6. TRANSFORM DATASET CLASS
# =====================================================================

class TransformDataset(Dataset):
    def __init__(self, subset, transform):
        self.subset = subset
        self.transform = transform

    def __len__(self):
        return len(self.subset)

    def __getitem__(self, idx):
        img_path = self.subset.dataset.images[self.subset.indices[idx]]
        label = self.subset.dataset.labels[self.subset.indices[idx]]

        try:
            image = Image.open(img_path).convert('RGB')
        except Exception as e:
            print(f"Error loading image {img_path}: {e}")
            image = Image.new('RGB', (224, 224), (0, 0, 0))

        if self.transform:
            image = self.transform(image)

        return image, label

# =====================================================================
# 7. TRAINING AND EVALUATION FUNCTIONS
# =====================================================================

def train_epoch(model, train_loader, criterion, optimizer, device):
    """Train for one epoch"""
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    pbar = tqdm(train_loader, desc='Training', leave=False)
    for inputs, labels in pbar:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * inputs.size(0)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        pbar.set_postfix({
            'loss': f'{loss.item():.4f}',
            'acc': f'{100.*correct/total:.2f}%'
        })

    epoch_loss = running_loss / len(train_loader.dataset)
    epoch_acc = 100. * correct / total

    return epoch_loss, epoch_acc

def evaluate(model, loader, criterion, device):
    """Evaluate the model"""
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        pbar = tqdm(loader, desc='Evaluating', leave=False)
        for inputs, labels in pbar:
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = model(inputs)
            loss = criterion(outputs, labels)

            running_loss += loss.item() * inputs.size(0)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

            pbar.set_postfix({
                'loss': f'{loss.item():.4f}',
                'acc': f'{100.*correct/total:.2f}%'
            })

    epoch_loss = running_loss / len(loader.dataset)
    epoch_acc = 100. * correct / total

    return epoch_loss, epoch_acc, all_preds, all_labels

def evaluate_detailed(model, loader, device):
    """Evaluate model with detailed metrics"""
    model.eval()
    all_preds = []
    all_labels = []

    with torch.no_grad():
        pbar = tqdm(loader, desc='Test Evaluation', leave=False)
        for inputs, labels in pbar:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)

            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    # Calculate metrics
    accuracy = accuracy_score(all_labels, all_preds) * 100
    precision = precision_score(all_labels, all_preds, average='weighted', zero_division=0) * 100
    recall = recall_score(all_labels, all_preds, average='weighted', zero_division=0) * 100
    f1 = f1_score(all_labels, all_preds, average='weighted', zero_division=0) * 100

    return {
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1_score': f1,
        'predictions': all_preds,
        'labels': all_labels
    }

# =====================================================================
# 8. K-FOLD CROSS VALIDATION SETUP
# =====================================================================

BATCH_SIZE = 64
NUM_WORKERS = 0
EPOCHS = 10
INITIAL_LR = 0.01
MOMENTUM = 0.9
WEIGHT_DECAY = 1e-4
N_FOLDS = 7

print("\n" + "="*60)
print("K-FOLD CROSS VALIDATION CONFIGURATION")
print("="*60)
print(f"✓ Number of folds: {N_FOLDS}")
print(f"✓ Epochs per fold: {EPOCHS}")
print(f"✓ Batch size: {BATCH_SIZE}")
print(f"✓ Initial LR: {INITIAL_LR}")
print(f"✓ Momentum: {MOMENTUM}")
print(f"✓ Weight Decay: {WEIGHT_DECAY}")
print(f"✓ Optimizer: SGD")
print(f"✓ Model: GhostNet-100")
print(f"⚠️  Data Augmentation: DISABLED")

# Setup K-Fold
indices = list(range(len(full_trainval_dataset)))
labels = full_trainval_dataset.labels

skf = StratifiedKFold(n_splits=N_FOLDS, shuffle=True, random_state=42)

# Store results for all folds
fold_histories = []
fold_test_evaluations = []

# =====================================================================
# 9. K-FOLD TRAINING LOOP WITH TEST SET EVALUATION
# =====================================================================

print("\n" + "="*60)
print("STARTING K-FOLD CROSS VALIDATION (NO AUGMENTATION)")
print("="*60)

for fold, (train_idx, val_idx) in enumerate(skf.split(indices, labels)):
    print(f"\n{'='*60}")
    print(f"FOLD {fold+1}/{N_FOLDS}")
    print(f"{'='*60}")

    # Create train and val subsets for this fold
    train_subset = Subset(full_trainval_dataset, train_idx)
    val_subset = Subset(full_trainval_dataset, val_idx)

    # Apply same transform to both (NO AUGMENTATION)
    train_dataset_fold = TransformDataset(train_subset, standard_transform)
    val_dataset_fold = TransformDataset(val_subset, standard_transform)

    # Create dataloaders
    train_loader = DataLoader(
        train_dataset_fold,
        batch_size=BATCH_SIZE,
        shuffle=True,
        num_workers=NUM_WORKERS,
        pin_memory=True if torch.cuda.is_available() else False
    )

    val_loader = DataLoader(
        val_dataset_fold,
        batch_size=BATCH_SIZE,
        shuffle=False,
        num_workers=NUM_WORKERS,
        pin_memory=True if torch.cuda.is_available() else False
    )

    # Initialize model
    model = timm.create_model('ghostnet_100', pretrained=True)
    num_ftrs = model.classifier.in_features
    print(f"✓ Feature dimension: {num_ftrs}")

    model.classifier = nn.Linear(num_ftrs, NUM_CLASSES)
    nn.init.normal_(model.classifier.weight, mean=0.0, std=0.01)
    nn.init.constant_(model.classifier.bias, 0)
    model = model.to(device)

    # Loss and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(
        model.parameters(),
        lr=INITIAL_LR,
        momentum=MOMENTUM,
        weight_decay=WEIGHT_DECAY,
        nesterov=True
    )

    scheduler = optim.lr_scheduler.StepLR(
        optimizer,
        step_size=10,
        gamma=0.1
    )

    # Training history for this fold
    fold_history = {
        'train_loss': [],
        'train_acc': [],
        'val_loss': [],
        'val_acc': [],
        'lr': []
    }

    best_val_acc = 0.0
    best_epoch = 0

    # Train for this fold
    for epoch in range(EPOCHS):
        current_lr = optimizer.param_groups[0]['lr']

        print(f"\nFold {fold+1} - Epoch {epoch+1}/{EPOCHS} | LR: {current_lr:.6f}")
        print("-" * 60)

        # Train
        train_loss, train_acc = train_epoch(model, train_loader, criterion, optimizer, device)

        # Validate
        val_loss, val_acc, _, _ = evaluate(model, val_loader, criterion, device)

        # Step scheduler
        old_lr = current_lr
        scheduler.step()
        new_lr = optimizer.param_groups[0]['lr']

        if new_lr < old_lr:
            print(f"📉 Learning rate reduced: {old_lr:.6f} → {new_lr:.6f}")

        # Save history
        fold_history['train_loss'].append(train_loss)
        fold_history['train_acc'].append(train_acc)
        fold_history['val_loss'].append(val_loss)
        fold_history['val_acc'].append(val_acc)
        fold_history['lr'].append(current_lr)

        # Print results
        print(f"Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}%")
        print(f"Val Loss:   {val_loss:.4f} | Val Acc:   {val_acc:.2f}%")

        # Track best validation accuracy
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            best_epoch = epoch + 1
            print(f"✓ New best validation accuracy! (Val Acc: {best_val_acc:.2f}%)")

    # =====================================================================
    # EVALUATE THE FINAL MODEL ON TEST SET
    # =====================================================================
    print(f"\n{'='*60}")
    print(f"EVALUATING FOLD {fold+1} ON TEST SET")
    print(f"{'='*60}")

    test_results = evaluate_detailed(model, test_loader, device)

    print(f"\n📊 Test Set Evaluation Results (Fold {fold+1}):")
    print(f"  • Accuracy:  {test_results['accuracy']:.2f}%")
    print(f"  • Precision: {test_results['precision']:.2f}%")
    print(f"  • Recall:    {test_results['recall']:.2f}%")
    print(f"  • F1-Score:  {test_results['f1_score']:.2f}%")

    # Save model with TEST results
    fold_model_path = f'/content/drive/MyDrive/GroceryStoreDataset/710fold{fold+1}_final_model_ghostnet_sgd_noaug.pth'
    torch.save({
        'fold': fold + 1,
        'epoch': EPOCHS,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'num_classes': NUM_CLASSES,
        'num_ftrs': num_ftrs,
        'test_evaluation_metrics': {
            'accuracy': test_results['accuracy'],
            'precision': test_results['precision'],
            'recall': test_results['recall'],
            'f1_score': test_results['f1_score']
        },
        'best_val_acc': best_val_acc,
        'best_val_epoch': best_epoch,
        'augmentation': False
    }, fold_model_path)
    print(f"✓ Model saved: {fold_model_path}")

    # Store fold TEST evaluation results
    fold_test_evaluations.append({
        'fold': fold + 1,
        'test_accuracy': test_results['accuracy'],
        'test_precision': test_results['precision'],
        'test_recall': test_results['recall'],
        'test_f1_score': test_results['f1_score'],
        'best_val_acc': best_val_acc,
        'best_val_epoch': best_epoch,
        'model_path': fold_model_path
    })

    # Store fold training history
    fold_histories.append(fold_history)

    print(f"\nFold {fold+1} Summary:")
    print(f"  • Val Acc: {best_val_acc:.2f}%")
    print(f"  • Test Accuracy: {test_results['accuracy']:.2f}%")
    print(f"  • Test F1-Score: {test_results['f1_score']:.2f}%")

# =====================================================================
# 10. K-FOLD TEST RESULTS SUMMARY
# =====================================================================

print("\n" + "="*60)
print("K-FOLD TEST SET EVALUATION RESULTS (NO AUGMENTATION)")
print("="*60)

# Create DataFrame for better visualization
test_eval_df = pd.DataFrame(fold_test_evaluations)

print("\nDetailed Test Results Per Fold:")
print(test_eval_df[['fold', 'test_accuracy', 'test_precision', 'test_recall', 'test_f1_score']].to_string(index=False))

print("\n" + "="*60)
print("SUMMARY STATISTICS (TEST SET)")
print("="*60)

# Calculate mean and std for each metric
test_metrics = ['test_accuracy', 'test_precision', 'test_recall', 'test_f1_score']
summary_stats = {}

for metric in test_metrics:
    values = test_eval_df[metric].values
    mean_val = np.mean(values)
    std_val = np.std(values)
    summary_stats[metric] = {'mean': mean_val, 'std': std_val}

    metric_name = metric.replace('test_', '').replace('_', ' ').title()
    print(f"\n{metric_name}:")
    print(f"  • Mean: {mean_val:.2f}%")
    print(f"  • Std:  {std_val:.2f}%")
    print(f"  • Min:  {np.min(values):.2f}%")
    print(f"  • Max:  {np.max(values):.2f}%")

# =====================================================================
# 11. SAVE RESULTS TO CSV
# =====================================================================

test_eval_df.to_csv('kfold_test_evaluation_results_noaug.csv', index=False)
print("\n✓ Test results saved to 'kfold_test_evaluation_results_noaug.csv'")

# Save summary statistics
summary_df = pd.DataFrame(summary_stats).T
summary_df.to_csv('kfold_test_summary_statistics_noaug.csv')
print("✓ Test summary statistics saved to 'kfold_test_summary_statistics_noaug.csv'")

# =====================================================================
# 12. PLOT K-FOLD TEST EVALUATION RESULTS
# =====================================================================

fig, axes = plt.subplots(2, 2, figsize=(15, 12))

# Plot 1: Test Accuracy per fold
ax = axes[0, 0]
folds = test_eval_df['fold'].values
accuracies = test_eval_df['test_accuracy'].values
ax.bar(folds, accuracies, color='steelblue', alpha=0.7)
ax.axhline(summary_stats['test_accuracy']['mean'], color='red', linestyle='--',
           label=f"Mean: {summary_stats['test_accuracy']['mean']:.2f}%")
ax.fill_between([0.5, N_FOLDS+0.5],
                summary_stats['test_accuracy']['mean'] - summary_stats['test_accuracy']['std'],
                summary_stats['test_accuracy']['mean'] + summary_stats['test_accuracy']['std'],
                alpha=0.2, color='red', label=f"±1 Std: {summary_stats['test_accuracy']['std']:.2f}%")
ax.set_xlabel('Fold')
ax.set_ylabel('Test Accuracy (%)')
ax.set_title('Test Accuracy per Fold (No Augmentation)')
ax.legend()
ax.grid(True, axis='y', alpha=0.3)
ax.set_xticks(folds)

# Plot 2: Test Precision per fold
ax = axes[0, 1]
precisions = test_eval_df['test_precision'].values
ax.bar(folds, precisions, color='green', alpha=0.7)
ax.axhline(summary_stats['test_precision']['mean'], color='red', linestyle='--',
           label=f"Mean: {summary_stats['test_precision']['mean']:.2f}%")
ax.fill_between([0.5, N_FOLDS+0.5],
                summary_stats['test_precision']['mean'] - summary_stats['test_precision']['std'],
                summary_stats['test_precision']['mean'] + summary_stats['test_precision']['std'],
                alpha=0.2, color='red', label=f"±1 Std: {summary_stats['test_precision']['std']:.2f}%")
ax.set_xlabel('Fold')
ax.set_ylabel('Test Precision (%)')
ax.set_title('Test Precision per Fold (No Augmentation)')
ax.legend()
ax.grid(True, axis='y', alpha=0.3)
ax.set_xticks(folds)

# Plot 3: Test Recall per fold
ax = axes[1, 0]
recalls = test_eval_df['test_recall'].values
ax.bar(folds, recalls, color='orange', alpha=0.7)
ax.axhline(summary_stats['test_recall']['mean'], color='red', linestyle='--',
           label=f"Mean: {summary_stats['test_recall']['mean']:.2f}%")
ax.fill_between([0.5, N_FOLDS+0.5],
                summary_stats['test_recall']['mean'] - summary_stats['test_recall']['std'],
                summary_stats['test_recall']['mean'] + summary_stats['test_recall']['std'],
                alpha=0.2, color='red', label=f"±1 Std: {summary_stats['test_recall']['std']:.2f}%")
ax.set_xlabel('Fold')
ax.set_ylabel('Test Recall (%)')
ax.set_title('Test Recall per Fold (No Augmentation)')
ax.legend()
ax.grid(True, axis='y', alpha=0.3)
ax.set_xticks(folds)

# Plot 4: Test F1-Score per fold
ax = axes[1, 1]
f1_scores = test_eval_df['test_f1_score'].values
ax.bar(folds, f1_scores, color='purple', alpha=0.7)
ax.axhline(summary_stats['test_f1_score']['mean'], color='red', linestyle='--',
           label=f"Mean: {summary_stats['test_f1_score']['mean']:.2f}%")
ax.fill_between([0.5, N_FOLDS+0.5],
                summary_stats['test_f1_score']['mean'] - summary_stats['test_f1_score']['std'],
                summary_stats['test_f1_score']['mean'] + summary_stats['test_f1_score']['std'],
                alpha=0.2, color='red', label=f"±1 Std: {summary_stats['test_f1_score']['std']:.2f}%")
ax.set_xlabel('Fold')
ax.set_ylabel('Test F1-Score (%)')
ax.set_title('Test F1-Score per Fold (No Augmentation)')
ax.legend()
ax.grid(True, axis='y', alpha=0.3)
ax.set_xticks(folds)

plt.tight_layout()
plt.savefig('kfold_test_evaluation_metrics_noaug.png', dpi=300, bbox_inches='tight')
plt.show()

# =====================================================================
# 13. PLOT ALL TEST METRICS COMPARISON
# =====================================================================

fig, ax = plt.subplots(figsize=(12, 6))

x = np.arange(N_FOLDS)
width = 0.2

ax.bar(x - 1.5*width, test_eval_df['test_accuracy'], width, label='Accuracy', color='steelblue', alpha=0.8)
ax.bar(x - 0.5*width, test_eval_df['test_precision'], width, label='Precision', color='green', alpha=0.8)
ax.bar(x + 0.5*width, test_eval_df['test_recall'], width, label='Recall', color='orange', alpha=0.8)
ax.bar(x + 1.5*width, test_eval_df['test_f1_score'], width, label='F1-Score', color='purple', alpha=0.8)

ax.set_xlabel('Fold', fontsize=12)
ax.set_ylabel('Test Score (%)', fontsize=12)
ax.set_title('All Test Metrics Comparison Across Folds (No Augmentation)', fontsize=14, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels([f'Fold {i+1}' for i in range(N_FOLDS)])
ax.legend()
ax.grid(True, axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig('kfold_test_all_metrics_comparison_noaug.png', dpi=300, bbox_inches='tight')
plt.show()

print("\n" + "="*60)
print("K-FOLD CROSS VALIDATION COMPLETE! (NO AUGMENTATION)")
print("="*60)
print("✓ All plots saved")
print("✓ Results saved to CSV files")
print(f"\n✓ Saved {N_FOLDS} model files with TEST evaluations:")
for i in range(1, N_FOLDS+1):
    print(f"  - fold{i}_final_model_ghostnet_sgd_noaug.pth")

print(f"\n📊 Final Test Set Performance (NO AUGMENTATION):")
print(f"  • Mean Accuracy:  {summary_stats['test_accuracy']['mean']:.2f}% ± {summary_stats['test_accuracy']['std']:.2f}%")
print(f"  • Mean Precision: {summary_stats['test_precision']['mean']:.2f}% ± {summary_stats['test_precision']['std']:.2f}%")
print(f"  • Mean Recall:    {summary_stats['test_recall']['mean']:.2f}% ± {summary_stats['test_recall']['std']:.2f}%")
print(f"  • Mean F1-Score:  {summary_stats['test_f1_score']['mean']:.2f}% ± {summary_stats['test_f1_score']['std']:.2f}%")
# Out:
# Using device: cuda
# GPU: Tesla T4
# Mounted at /content/drive
#
# ⚠️  DATA AUGMENTATION: DISABLED
# ✓ Using only basic transformations (Resize + CenterCrop + Normalize)
#
# ============================================================
# LOADING DATASETS
# ============================================================
#
# Loading dataset from: train, val
#   ✓ Found 81 unique classes
#   ✓ Images per class: min=20, max=75, avg=36.2
#
# Loading dataset from: test
#   ✓ Found 81 unique classes
#   ✓ Images per class: min=10, max=68, avg=30.7
#
# ✓ Total classes: 81
#
# ============================================================
# K-FOLD CROSS VALIDATION CONFIGURATION
# ============================================================
# ✓ Number of folds: 7
# ✓ Epochs per fold: 10
# ✓ Batch size: 64
# ✓ Initial LR: 0.01
# ✓ Momentum: 0.9
# ✓ Weight Decay: 0.0001
# ✓ Optimizer: SGD
# ✓ Model: GhostNet-100
# ⚠️  Data Augmentation: DISABLED
#
# ============================================================
# STARTING K-FOLD CROSS VALIDATION (NO AUGMENTATION)
# ============================================================
#
# ============================================================
# FOLD 1/7
# ============================================================
# model.safetensors:   0%|          | 0.00/20.9M [00:00<?, ?B/s]
# ✓ Feature dimension: 1280
#
# Fold 1 - Epoch 1/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 4.0196 | Train Acc: 19.59%
# Val Loss:   3.2712 | Val Acc:   40.95%
# ✓ New best validation accuracy! (Val Acc: 40.95%)
#
# Fold 1 - Epoch 2/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.1345 | Train Acc: 62.80%
# Val Loss:   1.1462 | Val Acc:   79.05%
# ✓ New best validation accuracy! (Val Acc: 79.05%)
#
# Fold 1 - Epoch 3/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.6250 | Train Acc: 89.03%
# Val Loss:   0.3991 | Val Acc:   91.90%
# ✓ New best validation accuracy! (Val Acc: 91.90%)
#
# Fold 1 - Epoch 4/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.2406 | Train Acc: 95.95%
# Val Loss:   0.2502 | Val Acc:   95.48%
# ✓ New best validation accuracy! (Val Acc: 95.48%)
#
# Fold 1 - Epoch 5/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.1237 | Train Acc: 98.09%
# Val Loss:   0.1755 | Val Acc:   97.14%
# ✓ New best validation accuracy! (Val Acc: 97.14%)
#
# Fold 1 - Epoch 6/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.0744 | Train Acc: 99.32%
# Val Loss:   0.1380 | Val Acc:   97.62%
# ✓ New best validation accuracy! (Val Acc: 97.62%)
#
# Fold 1 - Epoch 7/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.0484 | Train Acc: 99.64%
# Val Loss:   0.1266 | Val Acc:   97.86%
# ✓ New best validation accuracy! (Val Acc: 97.86%)
#
# Fold 1 - Epoch 8/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.0366 | Train Acc: 99.84%
# Val Loss:   0.1105 | Val Acc:   98.33%
# ✓ New best validation accuracy! (Val Acc: 98.33%)
#
# Fold 1 - Epoch 9/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.0298 | Train Acc: 99.72%
# Val Loss:   0.0955 | Val Acc:   98.10%
#
# Fold 1 - Epoch 10/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# 📉 Learning rate reduced: 0.010000 → 0.001000
# Train Loss: 0.0250 | Train Acc: 99.92%
# Val Loss:   0.0849 | Val Acc:   98.81%
# ✓ New best validation accuracy! (Val Acc: 98.81%)
#
# ============================================================
# EVALUATING FOLD 1 ON TEST SET
# ============================================================
# Test Evaluation:   0%|          | 0/39 [00:00<?, ?it/s]
# 📊 Test Set Evaluation Results (Fold 1):
#   • Accuracy:  85.47%
#   • Precision: 86.61%
#   • Recall:    85.47%
#   • F1-Score:  85.44%
# ✓ Model saved: /content/drive/MyDrive/GroceryStoreDataset/710fold1_final_model_ghostnet_sgd_noaug.pth
#
# Fold 1 Summary:
#   • Val Acc: 98.81%
#   • Test Accuracy: 85.47%
#   • Test F1-Score: 85.44%
#
# ============================================================
# FOLD 2/7
# ============================================================
# ✓ Feature dimension: 1280
#
# Fold 2 - Epoch 1/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 4.0415 | Train Acc: 17.61%
# Val Loss:   3.2548 | Val Acc:   42.62%
# ✓ New best validation accuracy! (Val Acc: 42.62%)
#
# Fold 2 - Epoch 2/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.1983 | Train Acc: 61.69%
# Val Loss:   1.0942 | Val Acc:   81.67%
# ✓ New best validation accuracy! (Val Acc: 81.67%)
#
# Fold 2 - Epoch 3/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.6568 | Train Acc: 88.79%
# Val Loss:   0.3565 | Val Acc:   93.81%
# ✓ New best validation accuracy! (Val Acc: 93.81%)
#
# Fold 2 - Epoch 4/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.2460 | Train Acc: 95.95%
# Val Loss:   0.2137 | Val Acc:   95.95%
# ✓ New best validation accuracy! (Val Acc: 95.95%)
#
# Fold 2 - Epoch 5/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.1271 | Train Acc: 98.57%
# Val Loss:   0.1507 | Val Acc:   96.43%
# ✓ New best validation accuracy! (Val Acc: 96.43%)
#
# Fold 2 - Epoch 6/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.0732 | Train Acc: 99.44%
# Val Loss:   0.1226 | Val Acc:   97.14%
# ✓ New best validation accuracy! (Val Acc: 97.14%)
#
# Fold 2 - Epoch 7/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.0557 | Train Acc: 99.60%
# Val Loss:   0.1034 | Val Acc:   97.38%
# ✓ New best validation accuracy! (Val Acc: 97.38%)
#
# Fold 2 - Epoch 8/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.0371 | Train Acc: 99.76%
# Val Loss:   0.0893 | Val Acc:   97.62%
# ✓ New best validation accuracy! (Val Acc: 97.62%)
#
# Fold 2 - Epoch 9/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.0286 | Train Acc: 99.96%
# Val Loss:   0.0878 | Val Acc:   97.62%
#
# Fold 2 - Epoch 10/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# 📉 Learning rate reduced: 0.010000 → 0.001000
# Train Loss: 0.0231 | Train Acc: 99.88%
# Val Loss:   0.0824 | Val Acc:   97.86%
# ✓ New best validation accuracy! (Val Acc: 97.86%)
#
# ============================================================
# EVALUATING FOLD 2 ON TEST SET
# ============================================================
# Test Evaluation:   0%|          | 0/39 [00:00<?, ?it/s]
# 📊 Test Set Evaluation Results (Fold 2):
#   • Accuracy:  85.51%
#   • Precision: 86.70%
#   • Recall:    85.51%
#   • F1-Score:  85.35%
# ✓ Model saved: /content/drive/MyDrive/GroceryStoreDataset/710fold2_final_model_ghostnet_sgd_noaug.pth
#
# Fold 2 Summary:
#   • Val Acc: 97.86%
#   • Test Accuracy: 85.51%
#   • Test F1-Score: 85.35%
#
# ============================================================
# FOLD 3/7
# ============================================================
# ✓ Feature dimension: 1280
#
# Fold 3 - Epoch 1/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 4.0488 | Train Acc: 16.97%
# Val Loss:   3.2657 | Val Acc:   41.19%
# ✓ New best validation accuracy! (Val Acc: 41.19%)
#
# Fold 3 - Epoch 2/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.2235 | Train Acc: 60.10%
# Val Loss:   1.1295 | Val Acc:   77.86%
# ✓ New best validation accuracy! (Val Acc: 77.86%)
#
# Fold 3 - Epoch 3/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.6563 | Train Acc: 88.71%
# Val Loss:   0.4199 | Val Acc:   91.90%
# ✓ New best validation accuracy! (Val Acc: 91.90%)
#
# Fold 3 - Epoch 4/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.2446 | Train Acc: 96.07%
# Val Loss:   0.2617 | Val Acc:   94.52%
# ✓ New best validation accuracy! (Val Acc: 94.52%)
#
# Fold 3 - Epoch 5/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.1200 | Train Acc: 98.65%
# Val Loss:   0.1984 | Val Acc:   95.95%
# ✓ New best validation accuracy! (Val Acc: 95.95%)
#
# Fold 3 - Epoch 6/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.0732 | Train Acc: 99.48%
# Val Loss:   0.1707 | Val Acc:   95.71%
#
# Fold 3 - Epoch 7/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.0493 | Train Acc: 99.64%
# Val Loss:   0.1657 | Val Acc:   95.95%
#
# Fold 3 - Epoch 8/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.0381 | Train Acc: 99.76%
# Val Loss:   0.1315 | Val Acc:   97.14%
# ✓ New best validation accuracy! (Val Acc: 97.14%)
#
# Fold 3 - Epoch 9/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.0297 | Train Acc: 99.80%
# Val Loss:   0.1304 | Val Acc:   95.95%
#
# Fold 3 - Epoch 10/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# 📉 Learning rate reduced: 0.010000 → 0.001000
# Train Loss: 0.0239 | Train Acc: 100.00%
# Val Loss:   0.1211 | Val Acc:   97.14%
#
# ============================================================
# EVALUATING FOLD 3 ON TEST SET
# ============================================================
# Test Evaluation:   0%|          | 0/39 [00:00<?, ?it/s]
# 📊 Test Set Evaluation Results (Fold 3):
#   • Accuracy:  86.20%
#   • Precision: 87.19%
#   • Recall:    86.20%
#   • F1-Score:  86.19%
# ✓ Model saved: /content/drive/MyDrive/GroceryStoreDataset/710fold3_final_model_ghostnet_sgd_noaug.pth
#
# Fold 3 Summary:
#   • Val Acc: 97.14%
#   • Test Accuracy: 86.20%
#   • Test F1-Score: 86.19%
#
# ============================================================
# FOLD 4/7
# ============================================================
# ✓ Feature dimension: 1280
#
# Fold 4 - Epoch 1/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 4.0485 | Train Acc: 17.64%
# Val Loss:   3.2637 | Val Acc:   41.53%
# ✓ New best validation accuracy! (Val Acc: 41.53%)
#
# Fold 4 - Epoch 2/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.1957 | Train Acc: 60.15%
# Val Loss:   1.1027 | Val Acc:   81.38%
# ✓ New best validation accuracy! (Val Acc: 81.38%)
#
# Fold 4 - Epoch 3/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.6431 | Train Acc: 89.67%
# Val Loss:   0.4061 | Val Acc:   91.17%
# ✓ New best validation accuracy! (Val Acc: 91.17%)
#
# Fold 4 - Epoch 4/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.2385 | Train Acc: 96.23%
# Val Loss:   0.2511 | Val Acc:   93.32%
# ✓ New best validation accuracy! (Val Acc: 93.32%)
#
# Fold 4 - Epoch 5/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.1258 | Train Acc: 98.41%
# Val Loss:   0.1888 | Val Acc:   95.70%
# ✓ New best validation accuracy! (Val Acc: 95.70%)
#
# Fold 4 - Epoch 6/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.0802 | Train Acc: 98.97%
# Val Loss:   0.1591 | Val Acc:   96.18%
# ✓ New best validation accuracy! (Val Acc: 96.18%)
#
# Fold 4 - Epoch 7/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.0642 | Train Acc: 99.21%
# Val Loss:   0.1344 | Val Acc:   97.14%
# ✓ New best validation accuracy! (Val Acc: 97.14%)
#
# Fold 4 - Epoch 8/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.0377 | Train Acc: 99.84%
# Val Loss:   0.1150 | Val Acc:   97.14%
#
# Fold 4 - Epoch 9/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.0314 | Train Acc: 99.84%
# Val Loss:   0.1045 | Val Acc:   97.37%
# ✓ New best validation accuracy! (Val Acc: 97.37%)
#
# Fold 4 - Epoch 10/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# 📉 Learning rate reduced: 0.010000 → 0.001000
# Train Loss: 0.0236 | Train Acc: 99.84%
# Val Loss:   0.1002 | Val Acc:   97.14%
#
# ============================================================
# EVALUATING FOLD 4 ON TEST SET
# ============================================================
# Test Evaluation:   0%|          | 0/39 [00:00<?, ?it/s]
# 📊 Test Set Evaluation Results (Fold 4):
#   • Accuracy:  84.95%
#   • Precision: 86.38%
#   • Recall:    84.95%
#   • F1-Score:  84.90%
# ✓ Model saved: /content/drive/MyDrive/GroceryStoreDataset/710fold4_final_model_ghostnet_sgd_noaug.pth
#
# Fold 4 Summary:
#   • Val Acc: 97.37%
#   • Test Accuracy: 84.95%
#   • Test F1-Score: 84.90%
#
# ============================================================
# FOLD 5/7
# ============================================================
# ✓ Feature dimension: 1280
#
# Fold 5 - Epoch 1/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 4.0356 | Train Acc: 16.41%
# Val Loss:   3.2653 | Val Acc:   42.48%
# ✓ New best validation accuracy! (Val Acc: 42.48%)
#
# Fold 5 - Epoch 2/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.1794 | Train Acc: 59.83%
# Val Loss:   1.1821 | Val Acc:   77.57%
# ✓ New best validation accuracy! (Val Acc: 77.57%)
#
# Fold 5 - Epoch 3/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.6567 | Train Acc: 88.99%
# Val Loss:   0.4703 | Val Acc:   89.26%
# ✓ New best validation accuracy! (Val Acc: 89.26%)
#
# Fold 5 - Epoch 4/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.2296 | Train Acc: 96.38%
# Val Loss:   0.2921 | Val Acc:   93.08%
# ✓ New best validation accuracy! (Val Acc: 93.08%)
#
# Fold 5 - Epoch 5/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.1162 | Train Acc: 98.73%
# Val Loss:   0.2172 | Val Acc:   94.99%
# ✓ New best validation accuracy! (Val Acc: 94.99%)
#
# Fold 5 - Epoch 6/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.0749 | Train Acc: 99.28%
# Val Loss:   0.1877 | Val Acc:   95.70%
# ✓ New best validation accuracy! (Val Acc: 95.70%)
#
# Fold 5 - Epoch 7/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.0544 | Train Acc: 99.44%
# Val Loss:   0.1536 | Val Acc:   95.94%
# ✓ New best validation accuracy! (Val Acc: 95.94%)
#
# Fold 5 - Epoch 8/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.0424 | Train Acc: 99.56%
# Val Loss:   0.1420 | Val Acc:   96.18%
# ✓ New best validation accuracy! (Val Acc: 96.18%)
#
# Fold 5 - Epoch 9/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.0325 | Train Acc: 99.88%
# Val Loss:   0.1428 | Val Acc:   96.18%
#
# Fold 5 - Epoch 10/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# 📉 Learning rate reduced: 0.010000 → 0.001000
# Train Loss: 0.0231 | Train Acc: 99.92%
# Val Loss:   0.1370 | Val Acc:   95.94%
#
# ============================================================
# EVALUATING FOLD 5 ON TEST SET
# ============================================================
# Test Evaluation:   0%|          | 0/39 [00:00<?, ?it/s]
# 📊 Test Set Evaluation Results (Fold 5):
#   • Accuracy:  85.51%
#   • Precision: 86.38%
#   • Recall:    85.51%
#   • F1-Score:  85.41%
# ✓ Model saved: /content/drive/MyDrive/GroceryStoreDataset/710fold5_final_model_ghostnet_sgd_noaug.pth
#
# Fold 5 Summary:
#   • Val Acc: 96.18%
#   • Test Accuracy: 85.51%
#   • Test F1-Score: 85.41%
#
# ============================================================
# FOLD 6/7
# ============================================================
# ✓ Feature dimension: 1280
#
# Fold 6 - Epoch 1/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 4.0417 | Train Acc: 18.55%
# Val Loss:   3.2910 | Val Acc:   41.77%
# ✓ New best validation accuracy! (Val Acc: 41.77%)
#
# Fold 6 - Epoch 2/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.2231 | Train Acc: 61.46%
# Val Loss:   1.2051 | Val Acc:   79.24%
# ✓ New best validation accuracy! (Val Acc: 79.24%)
#
# Fold 6 - Epoch 3/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.6932 | Train Acc: 87.92%
# Val Loss:   0.4422 | Val Acc:   90.69%
# ✓ New best validation accuracy! (Val Acc: 90.69%)
#
# Fold 6 - Epoch 4/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.2337 | Train Acc: 96.27%
# Val Loss:   0.2866 | Val Acc:   94.27%
# ✓ New best validation accuracy! (Val Acc: 94.27%)
#
# Fold 6 - Epoch 5/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.1296 | Train Acc: 98.29%
# Val Loss:   0.2135 | Val Acc:   95.47%
# ✓ New best validation accuracy! (Val Acc: 95.47%)
#
# Fold 6 - Epoch 6/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.0786 | Train Acc: 99.13%
# Val Loss:   0.1725 | Val Acc:   96.18%
# ✓ New best validation accuracy! (Val Acc: 96.18%)
#
# Fold 6 - Epoch 7/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.0535 | Train Acc: 99.52%
# Val Loss:   0.1540 | Val Acc:   96.66%
# ✓ New best validation accuracy! (Val Acc: 96.66%)
#
# Fold 6 - Epoch 8/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.0371 | Train Acc: 99.72%
# Val Loss:   0.1447 | Val Acc:   96.42%
#
# Fold 6 - Epoch 9/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.0300 | Train Acc: 99.80%
# Val Loss:   0.1283 | Val Acc:   96.90%
# ✓ New best validation accuracy! (Val Acc: 96.90%)
#
# Fold 6 - Epoch 10/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# 📉 Learning rate reduced: 0.010000 → 0.001000
# Train Loss: 0.0242 | Train Acc: 99.80%
# Val Loss:   0.1211 | Val Acc:   97.37%
# ✓ New best validation accuracy! (Val Acc: 97.37%)
#
# ============================================================
# EVALUATING FOLD 6 ON TEST SET
# ============================================================
# Test Evaluation:   0%|          | 0/39 [00:00<?, ?it/s]
# 📊 Test Set Evaluation Results (Fold 6):
#   • Accuracy:  85.92%
#   • Precision: 87.01%
#   • Recall:    85.92%
#   • F1-Score:  85.88%
# ✓ Model saved: /content/drive/MyDrive/GroceryStoreDataset/710fold6_final_model_ghostnet_sgd_noaug.pth
#
# Fold 6 Summary:
#   • Val Acc: 97.37%
#   • Test Accuracy: 85.92%
#   • Test F1-Score: 85.88%
#
# ============================================================
# FOLD 7/7
# ============================================================
# ✓ Feature dimension: 1280
#
# Fold 7 - Epoch 1/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 4.0410 | Train Acc: 16.01%
# Val Loss:   3.3080 | Val Acc:   39.38%
# ✓ New best validation accuracy! (Val Acc: 39.38%)
#
# Fold 7 - Epoch 2/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.2400 | Train Acc: 59.95%
# Val Loss:   1.2209 | Val Acc:   81.38%
# ✓ New best validation accuracy! (Val Acc: 81.38%)
#
# Fold 7 - Epoch 3/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.6905 | Train Acc: 88.12%
# Val Loss:   0.4437 | Val Acc:   91.41%
# ✓ New best validation accuracy! (Val Acc: 91.41%)
#
# Fold 7 - Epoch 4/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.2568 | Train Acc: 95.35%
# Val Loss:   0.2617 | Val Acc:   94.27%
# ✓ New best validation accuracy! (Val Acc: 94.27%)
#
# Fold 7 - Epoch 5/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.1294 | Train Acc: 97.97%
# Val Loss:   0.2191 | Val Acc:   94.51%
# ✓ New best validation accuracy! (Val Acc: 94.51%)
#
# Fold 7 - Epoch 6/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.0820 | Train Acc: 99.25%
# Val Loss:   0.1614 | Val Acc:   95.94%
# ✓ New best validation accuracy! (Val Acc: 95.94%)
#
# Fold 7 - Epoch 7/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.0489 | Train Acc: 99.56%
# Val Loss:   0.1467 | Val Acc:   96.66%
# ✓ New best validation accuracy! (Val Acc: 96.66%)
#
# Fold 7 - Epoch 8/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.0372 | Train Acc: 99.92%
# Val Loss:   0.1252 | Val Acc:   96.42%
#
# Fold 7 - Epoch 9/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 0.0308 | Train Acc: 99.88%
# Val Loss:   0.1280 | Val Acc:   96.42%
#
# Fold 7 - Epoch 10/10 | LR: 0.010000
# ------------------------------------------------------------
# Training:   0%|          | 0/40 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# 📉 Learning rate reduced: 0.010000 → 0.001000
# Train Loss: 0.0264 | Train Acc: 99.84%
# Val Loss:   0.1154 | Val Acc:   96.42%
#
# ============================================================
# EVALUATING FOLD 7 ON TEST SET
# ============================================================
# Test Evaluation:   0%|          | 0/39 [00:00<?, ?it/s]
# 📊 Test Set Evaluation Results (Fold 7):
#   • Accuracy:  84.95%
#   • Precision: 86.32%
#   • Recall:    84.95%
#   • F1-Score:  84.94%
# ✓ Model saved: /content/drive/MyDrive/GroceryStoreDataset/710fold7_final_model_ghostnet_sgd_noaug.pth
#
# Fold 7 Summary:
#   • Val Acc: 96.66%
#   • Test Accuracy: 84.95%
#   • Test F1-Score: 84.94%
#
# ============================================================
# K-FOLD TEST SET EVALUATION RESULTS (NO AUGMENTATION)
# ============================================================
#
# Detailed Test Results Per Fold:
#  fold  test_accuracy  test_precision  test_recall  test_f1_score
#     1      85.472837       86.614283    85.472837      85.442220
#     2      85.513078       86.703827    85.513078      85.350447
#     3      86.197183       87.186256    86.197183      86.194646
#     4      84.949698       86.383199    84.949698      84.902418
#     5      85.513078       86.379610    85.513078      85.414614
#     6      85.915493       87.005318    85.915493      85.876689
#     7      84.949698       86.319055    84.949698      84.943860
#
# ============================================================
# SUMMARY STATISTICS (TEST SET)
# ============================================================
#
# Accuracy:
#   • Mean: 85.50%
#   • Std:  0.43%
#   • Min:  84.95%
#   • Max:  86.20%
#
# Precision:
#   • Mean: 86.66%
#   • Std:  0.31%
#   • Min:  86.32%
#   • Max:  87.19%
#
# Recall:
#   • Mean: 85.50%
#   • Std:  0.43%
#   • Min:  84.95%
#   • Max:  86.20%
#
# F1 Score:
#   • Mean: 85.45%
#   • Std:  0.43%
#   • Min:  84.90%
#   • Max:  86.19%
#
# ✓ Test results saved to 'kfold_test_evaluation_results_noaug.csv'
# ✓ Test summary statistics saved to 'kfold_test_summary_statistics_noaug.csv'
# ============================================================
# K-FOLD CROSS VALIDATION COMPLETE! (NO AUGMENTATION)
# ============================================================
# ✓ All plots saved
# ✓ Results saved to CSV files
#
# ✓ Saved 7 model files with TEST evaluations:
#   - fold1_final_model_ghostnet_sgd_noaug.pth
#   - fold2_final_model_ghostnet_sgd_noaug.pth
#   - fold3_final_model_ghostnet_sgd_noaug.pth
#   - fold4_final_model_ghostnet_sgd_noaug.pth
#   - fold5_final_model_ghostnet_sgd_noaug.pth
#   - fold6_final_model_ghostnet_sgd_noaug.pth
#   - fold7_final_model_ghostnet_sgd_noaug.pth
#
# 📊 Final Test Set Performance (NO AUGMENTATION):
#   • Mean Accuracy:  85.50% ± 0.43%
#   • Mean Precision: 86.66% ± 0.31%
#   • Mean Recall:    85.50% ± 0.43%
#   • Mean F1-Score:  85.45% ± 0.43%

# %%
# =====================================================================
# VISUALISASI METRICS DARI CHECKPOINT (TANPA RE-EVALUATE)
# Extract saved test metrics langsung dari .pth files
# =====================================================================

import os
import torch
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set style
sns.set_style("whitegrid")

# =====================================================================
# 1. EXTRACT METRICS FROM CHECKPOINTS
# =====================================================================

MODEL_DIR = '/content/drive/MyDrive/GroceryStoreDataset'

print("="*70)
print("📊 EXTRACTING SAVED METRICS FROM CHECKPOINTS")
print("="*70)

all_fold_metrics = {}

for fold in range(1, 8):
    model_path = os.path.join(MODEL_DIR, f'710fold{fold}_final_model_ghostnet_sgd_noaug.pth')

    if not os.path.exists(model_path):
        print(f"⚠️  Fold {fold}: File not found")
        continue

    try:
        checkpoint = torch.load(model_path, map_location='cpu')

        if 'test_evaluation_metrics' in checkpoint:
            metrics = checkpoint['test_evaluation_metrics']

            # Extract metrics
            fold_results = {
                'accuracy': metrics.get('accuracy', 0),
                'precision': metrics.get('precision', 0),
                'recall': metrics.get('recall', 0),
                'f1_score': metrics.get('f1_score', 0)
            }

            all_fold_metrics[fold] = fold_results

            print(f"\n✅ Fold {fold}:")
            print(f"   • Accuracy:  {fold_results['accuracy']:.4f}")
            print(f"   • Precision: {fold_results['precision']:.4f}")
            print(f"   • Recall:    {fold_results['recall']:.4f}")
            print(f"   • F1-Score:  {fold_results['f1_score']:.4f}")
        else:
            print(f"⚠️  Fold {fold}: No 'test_evaluation_metrics' found in checkpoint")

    except Exception as e:
        print(f"❌ Fold {fold}: Error - {e}")
        continue

print("\n" + "="*70)
print(f"✅ EXTRACTED METRICS FROM {len(all_fold_metrics)}/7 FOLDS")
print("="*70)

if len(all_fold_metrics) == 0:
    print("\n❌ No metrics found! Please check checkpoint structure.")
else:
    # =====================================================================
    # 2. PREPARE DATA
    # =====================================================================

    folds = sorted(all_fold_metrics.keys())

    accuracies = [all_fold_metrics[f]['accuracy'] for f in folds]
    precisions = [all_fold_metrics[f]['precision'] for f in folds]
    recalls = [all_fold_metrics[f]['recall'] for f in folds]
    f1_scores = [all_fold_metrics[f]['f1_score'] for f in folds]

    # Convert percentage to decimal if needed
    if max(accuracies) > 1.5:  # Likely in percentage format
        accuracies = [a/100 for a in accuracies]
        precisions = [p/100 for p in precisions]
        recalls = [r/100 for r in recalls]
        f1_scores = [f/100 for f in f1_scores]
        print("\n✅ Converted percentages to decimal format")

    # Calculate statistics
    print(f"\n📈 OVERALL STATISTICS (Across {len(folds)} folds):")
    print(f"{'='*70}")

    metrics_summary = {
        'Accuracy': accuracies,
        'Precision': precisions,
        'Recall': recalls,
        'F1-Score': f1_scores
    }

    for metric_name, values in metrics_summary.items():
        mean_val = np.mean(values)
        std_val = np.std(values)
        min_val = np.min(values)
        max_val = np.max(values)
        print(f"\n{metric_name}:")
        print(f"  • Mean: {mean_val:.4f} ± {std_val:.4f}")
        print(f"  • Min:  {min_val:.4f}")
        print(f"  • Max:  {max_val:.4f}")
        print(f"  • Range: {max_val - min_val:.4f}")

    # =====================================================================
    # 3. VISUALIZATIONS (ALL VIRIDIS!)
    # =====================================================================

    print("\n" + "="*70)
    print("🎨 CREATING VISUALIZATIONS WITH VIRIDIS COLORMAP")
    print("="*70)

    # Get viridis colors
    viridis = sns.color_palette("viridis", 7)

    # ============================================
    # PLOT 1: Line Plot - All Metrics Across Folds
    # ============================================
    fig, ax = plt.subplots(figsize=(14, 8))

    x = np.array(folds)
    ax.plot(x, accuracies, marker='o', linewidth=2.5, markersize=10,
            label='Accuracy', color=viridis[0])
    ax.plot(x, precisions, marker='s', linewidth=2.5, markersize=10,
            label='Precision', color=viridis[2])
    ax.plot(x, recalls, marker='^', linewidth=2.5, markersize=10,
            label='Recall', color=viridis[4])
    ax.plot(x, f1_scores, marker='D', linewidth=2.5, markersize=10,
            label='F1-Score', color=viridis[6])

    ax.set_xlabel('Fold', fontsize=14, fontweight='bold')
    ax.set_ylabel('Score', fontsize=14, fontweight='bold')
    ax.set_title('Test Metrics Comparison Across 7 Folds - GhostNet + SGD',
                 fontsize=16, fontweight='bold', pad=20)
    ax.set_xticks(folds)
    ax.set_ylim([0.80, 0.95])
    ax.legend(fontsize=12, loc='lower right')
    ax.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()

    # ============================================
    # PLOT 2: Grouped Bar Chart (MAIN CHART - LIKE YOUR IMAGE!)
    # ============================================
    fig, ax = plt.subplots(figsize=(18, 8))

    x = np.arange(len(folds))
    width = 0.2

    # Use viridis colors
    bars1 = ax.bar(x - 1.5*width, [v*100 for v in accuracies], width, label='Accuracy',
                   color=viridis[0], edgecolor='black', linewidth=0.8)
    bars2 = ax.bar(x - 0.5*width, [v*100 for v in precisions], width, label='Precision',
                   color=viridis[2], edgecolor='black', linewidth=0.8)
    bars3 = ax.bar(x + 0.5*width, [v*100 for v in recalls], width, label='Recall',
                   color=viridis[4], edgecolor='black', linewidth=0.8)
    bars4 = ax.bar(x + 1.5*width, [v*100 for v in f1_scores], width, label='F1-Score',
                   color=viridis[6], edgecolor='black', linewidth=0.8)

    ax.set_xlabel('Fold', fontsize=13, fontweight='bold')
    ax.set_ylabel('Test Score (%)', fontsize=13, fontweight='bold')
    ax.set_title('All Test Metrics Comparison Across Folds',
                 fontsize=15, fontweight='bold', pad=20)
    ax.set_xticks(x)
    ax.set_xticklabels([f'Fold {f}' for f in folds], fontsize=11)
    ax.set_ylim([0, 105])  # Extend upper limit to give space
    ax.set_xlim([-0.8, len(folds) - 0.2])  # Add padding on left and right
    ax.legend(fontsize=11, loc='upper right', framealpha=0.9,
              bbox_to_anchor=(1.0, 1.0))  # Position legend inside plot area
    ax.grid(axis='y', alpha=0.3, linestyle='--')

    plt.tight_layout()
    plt.show()

    # ============================================
    # PLOT 3: Box Plot - Distribution Across Folds
    # ============================================
    fig, ax = plt.subplots(figsize=(12, 8))

    data_to_plot = [accuracies, precisions, recalls, f1_scores]
    bp = ax.boxplot(data_to_plot, labels=['Accuracy', 'Precision', 'Recall', 'F1-Score'],
                    patch_artist=True, widths=0.6)

    # Color the boxes with viridis
    colors = [viridis[0], viridis[2], viridis[4], viridis[6]]
    for patch, color in zip(bp['boxes'], colors):
        patch.set_facecolor(color)
        patch.set_edgecolor('black')
        patch.set_alpha(0.7)

    for median in bp['medians']:
        median.set_color('red')
        median.set_linewidth(2.5)

    ax.set_ylabel('Score', fontsize=14, fontweight='bold')
    ax.set_title('Metrics Distribution Across 7 Folds - Box Plot',
                 fontsize=16, fontweight='bold', pad=20)
    ax.set_ylim([0.80, 0.95])
    ax.grid(axis='y', alpha=0.3)

    plt.tight_layout()
    plt.show()

    # ============================================
    # PLOT 4: Heatmap - Metrics per Fold
    # ============================================
    fig, ax = plt.subplots(figsize=(14, 7))

    # Create data matrix
    metrics_matrix = np.array([accuracies, precisions, recalls, f1_scores])

    # Create heatmap
    im = ax.imshow(metrics_matrix, cmap='viridis', aspect='auto', vmin=0.80, vmax=0.95)

    # Set ticks
    ax.set_xticks(np.arange(len(folds)))
    ax.set_yticks(np.arange(4))
    ax.set_xticklabels([f'Fold {f}' for f in folds], fontsize=12)
    ax.set_yticklabels(['Accuracy', 'Precision', 'Recall', 'F1-Score'], fontsize=12)

    # Add text annotations
    for i in range(4):
        for j in range(len(folds)):
            text = ax.text(j, i, f'{metrics_matrix[i, j]:.4f}',
                          ha="center", va="center", color="white",
                          fontsize=12, fontweight='bold')

    ax.set_title('Metrics Heatmap - All Folds', fontsize=16, fontweight='bold', pad=20)
    cbar = plt.colorbar(im, ax=ax, label='Score')
    cbar.ax.tick_params(labelsize=11)

    plt.tight_layout()
    plt.show()

    # ============================================
    # PLOT 5: Mean with Error Bars (MAIN OVERALL CHART!)
    # ============================================
    fig, ax = plt.subplots(figsize=(14, 9))

    metric_names = ['Accuracy', 'Precision', 'Recall', 'F1-Score']
    means = [np.mean(accuracies), np.mean(precisions), np.mean(recalls), np.mean(f1_scores)]
    stds = [np.std(accuracies), np.std(precisions), np.std(recalls), np.std(f1_scores)]

    x_pos = np.arange(len(metric_names))
    bars = ax.bar(x_pos, means, yerr=stds, capsize=15,
                  color=[viridis[0], viridis[2], viridis[4], viridis[6]],
                  edgecolor='black', linewidth=2, alpha=0.85,
                  error_kw={'linewidth': 3, 'ecolor': 'red'})

    ax.set_xticks(x_pos)
    ax.set_xticklabels(metric_names, fontsize=15, fontweight='bold')
    ax.set_ylabel('Score', fontsize=16, fontweight='bold')
    ax.set_title('Overall Statistics Across 7 Folds - Mean ± Std Dev\nGhostNet + SGD',
                 fontsize=18, fontweight='bold', pad=25)
    ax.set_ylim([0.84, 0.89])
    ax.grid(axis='y', alpha=0.4, linewidth=1.5)

    # Add value labels
    for bar, mean, std in zip(bars, means, stds):
        height = bar.get_height()
        # Mean value on top
        ax.text(bar.get_x() + bar.get_width()/2., height + std + 0.0015,
                f'{mean:.4f}',
                ha='center', va='bottom', fontsize=14, fontweight='bold')
        # Std dev inside bar
        ax.text(bar.get_x() + bar.get_width()/2., height - 0.003,
                f'±{std:.4f}',
                ha='center', va='top', fontsize=12, color='white', fontweight='bold')

    plt.tight_layout()
    plt.show()

    print("\n" + "="*70)
    print("✅ VISUALIZATION COMPLETE!")
    print("="*70)
    print(f"\n📊 Summary:")
    print(f"   • Total folds visualized: {len(folds)}")
    print(f"   • Average Accuracy: {np.mean(accuracies):.4f} ± {np.std(accuracies):.4f}")
    print(f"   • Average F1-Score: {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
    print(f"   • Best performing fold: Fold {folds[np.argmax(accuracies)]} (Acc: {max(accuracies):.4f})")
    print(f"   • Worst performing fold: Fold {folds[np.argmin(accuracies)]} (Acc: {min(accuracies):.4f})")
    print(f"   • All visualizations use viridis colormap ✓")
    print("="*70)
# Out:
# ======================================================================
# 📊 EXTRACTING SAVED METRICS FROM CHECKPOINTS
# ======================================================================
#
# ✅ Fold 1:
#    • Accuracy:  85.4728
#    • Precision: 86.6143
#    • Recall:    85.4728
#    • F1-Score:  85.4422
#
# ✅ Fold 2:
#    • Accuracy:  85.5131
#    • Precision: 86.7038
#    • Recall:    85.5131
#    • F1-Score:  85.3504
#
# ✅ Fold 3:
#    • Accuracy:  86.1972
#    • Precision: 87.1863
#    • Recall:    86.1972
#    • F1-Score:  86.1946
#
# ✅ Fold 4:
#    • Accuracy:  84.9497
#    • Precision: 86.3832
#    • Recall:    84.9497
#    • F1-Score:  84.9024
#
# ✅ Fold 5:
#    • Accuracy:  85.5131
#    • Precision: 86.3796
#    • Recall:    85.5131
#    • F1-Score:  85.4146
#
# ✅ Fold 6:
#    • Accuracy:  85.9155
#    • Precision: 87.0053
#    • Recall:    85.9155
#    • F1-Score:  85.8767
#
# ✅ Fold 7:
#    • Accuracy:  84.9497
#    • Precision: 86.3191
#    • Recall:    84.9497
#    • F1-Score:  84.9439
#
# ======================================================================
# ✅ EXTRACTED METRICS FROM 7/7 FOLDS
# ======================================================================
#
# ✅ Converted percentages to decimal format
#
# 📈 OVERALL STATISTICS (Across 7 folds):
# ======================================================================
#
# Accuracy:
#   • Mean: 0.8550 ± 0.0043
#   • Min:  0.8495
#   • Max:  0.8620
#   • Range: 0.0125
#
# Precision:
#   • Mean: 0.8666 ± 0.0031
#   • Min:  0.8632
#   • Max:  0.8719
#   • Range: 0.0087
#
# Recall:
#   • Mean: 0.8550 ± 0.0043
#   • Min:  0.8495
#   • Max:  0.8620
#   • Range: 0.0125
#
# F1-Score:
#   • Mean: 0.8545 ± 0.0043
#   • Min:  0.8490
#   • Max:  0.8619
#   • Range: 0.0129
#
# ======================================================================
# 🎨 CREATING VISUALIZATIONS WITH VIRIDIS COLORMAP
# ======================================================================
# /tmp/ipython-input-1289938565.py:187: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp = ax.boxplot(data_to_plot, labels=['Accuracy', 'Precision', 'Recall', 'F1-Score'],
# ======================================================================
# ✅ VISUALIZATION COMPLETE!
# ======================================================================
#
# 📊 Summary:
#    • Total folds visualized: 7
#    • Average Accuracy: 0.8550 ± 0.0043
#    • Average F1-Score: 0.8545 ± 0.0043
#    • Best performing fold: Fold 3 (Acc: 0.8620)
#    • Worst performing fold: Fold 4 (Acc: 0.8495)
#    • All visualizations use viridis colormap ✓
# ======================================================================

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set seaborn style
sns.set_style("whitegrid")
sns.set_context("notebook", font_scale=1.2)
sns.set_palette("husl")

# ============================================================
# EXTRACTED DATA FROM TRAINING LOGS (NO AUGMENTATION - 7 FOLDS, 10 EPOCHS)
# ============================================================

training_data = {
    'fold1': {
        'epochs': list(range(1, 11)),
        'train_loss': [4.0196, 2.1345, 0.6250, 0.2406, 0.1237, 0.0744, 0.0484, 0.0366, 0.0298, 0.0250],
        'val_loss': [3.2712, 1.1462, 0.3991, 0.2502, 0.1755, 0.1380, 0.1266, 0.1105, 0.0955, 0.0849],
        'train_acc': [19.59, 62.80, 89.03, 95.95, 98.09, 99.32, 99.64, 99.84, 99.72, 99.92],
        'val_acc': [40.95, 79.05, 91.90, 95.48, 97.14, 97.62, 97.86, 98.33, 98.10, 98.81],
        'test_acc': 85.47
    },
    'fold2': {
        'epochs': list(range(1, 11)),
        'train_loss': [4.0415, 2.1983, 0.6568, 0.2460, 0.1271, 0.0732, 0.0557, 0.0371, 0.0286, 0.0231],
        'val_loss': [3.2548, 1.0942, 0.3565, 0.2137, 0.1507, 0.1226, 0.1034, 0.0893, 0.0878, 0.0824],
        'train_acc': [17.61, 61.69, 88.79, 95.95, 98.57, 99.44, 99.60, 99.76, 99.96, 99.88],
        'val_acc': [42.62, 81.67, 93.81, 95.95, 96.43, 97.14, 97.38, 97.62, 97.62, 97.86],
        'test_acc': 85.51
    },
    'fold3': {
        'epochs': list(range(1, 11)),
        'train_loss': [4.0488, 2.2235, 0.6563, 0.2446, 0.1200, 0.0732, 0.0493, 0.0381, 0.0297, 0.0239],
        'val_loss': [3.2657, 1.1295, 0.4199, 0.2617, 0.1984, 0.1707, 0.1657, 0.1315, 0.1304, 0.1211],
        'train_acc': [16.97, 60.10, 88.71, 96.07, 98.65, 99.48, 99.64, 99.76, 99.80, 100.00],
        'val_acc': [41.19, 77.86, 91.90, 94.52, 95.95, 95.71, 95.95, 97.14, 95.95, 97.14],
        'test_acc': 86.20
    },
    'fold4': {
        'epochs': list(range(1, 11)),
        'train_loss': [4.0485, 2.1957, 0.6431, 0.2385, 0.1258, 0.0802, 0.0642, 0.0377, 0.0314, 0.0236],
        'val_loss': [3.2637, 1.1027, 0.4061, 0.2511, 0.1888, 0.1591, 0.1344, 0.1150, 0.1045, 0.1002],
        'train_acc': [17.64, 60.15, 89.67, 96.23, 98.41, 98.97, 99.21, 99.84, 99.84, 99.84],
        'val_acc': [41.53, 81.38, 91.17, 93.32, 95.70, 96.18, 97.14, 97.14, 97.37, 97.14],
        'test_acc': 84.95
    },
    'fold5': {
        'epochs': list(range(1, 11)),
        'train_loss': [4.0356, 2.1794, 0.6567, 0.2296, 0.1162, 0.0749, 0.0544, 0.0424, 0.0325, 0.0231],
        'val_loss': [3.2653, 1.1821, 0.4703, 0.2921, 0.2172, 0.1877, 0.1536, 0.1420, 0.1428, 0.1370],
        'train_acc': [16.41, 59.83, 88.99, 96.38, 98.73, 99.28, 99.44, 99.56, 99.88, 99.92],
        'val_acc': [42.48, 77.57, 89.26, 93.08, 94.99, 95.70, 95.94, 96.18, 96.18, 95.94],
        'test_acc': 85.51
    },
    'fold6': {
        'epochs': list(range(1, 11)),
        'train_loss': [4.0417, 2.2231, 0.6932, 0.2337, 0.1296, 0.0786, 0.0535, 0.0371, 0.0300, 0.0242],
        'val_loss': [3.2910, 1.2051, 0.4422, 0.2866, 0.2135, 0.1725, 0.1540, 0.1447, 0.1283, 0.1211],
        'train_acc': [18.55, 61.46, 87.92, 96.27, 98.29, 99.13, 99.52, 99.72, 99.80, 99.80],
        'val_acc': [41.77, 79.24, 90.69, 94.27, 95.47, 96.18, 96.66, 96.42, 96.90, 97.37],
        'test_acc': 85.92
    },
    'fold7': {
        'epochs': list(range(1, 11)),
        'train_loss': [4.0410, 2.2400, 0.6905, 0.2568, 0.1294, 0.0820, 0.0489, 0.0372, 0.0308, 0.0264],
        'val_loss': [3.3080, 1.2209, 0.4437, 0.2617, 0.2191, 0.1614, 0.1467, 0.1252, 0.1280, 0.1154],
        'train_acc': [16.01, 59.95, 88.12, 95.35, 97.97, 99.25, 99.56, 99.92, 99.88, 99.84],
        'val_acc': [39.38, 81.38, 91.41, 94.27, 94.51, 95.94, 96.66, 96.42, 96.42, 96.42],
        'test_acc': 84.95
    }
}

# ============================================================
# 1. VALIDATION ERROR (VAL LOSS) - ALL FOLDS
# ============================================================

fig, ax = plt.subplots(figsize=(14, 8))

# Plot individual folds
colors = sns.color_palette("husl", 7)
for idx, (fold_name, fold_data) in enumerate(training_data.items()):
    ax.plot(fold_data['epochs'], fold_data['val_loss'],
            marker='o', linewidth=2, alpha=0.7,
            label=f'{fold_name.upper()}', color=colors[idx])

# Calculate and plot average
epochs = list(range(1, 11))
avg_val_loss = [np.mean([training_data[f'fold{i}']['val_loss'][e-1] for i in range(1, 8)])
                for e in epochs]
ax.plot(epochs, avg_val_loss,
        marker='s', linewidth=3.5, color='black',
        label='AVERAGE', linestyle='--', markersize=8)

ax.set_xlabel('Epoch', fontsize=14, fontweight='bold')
ax.set_ylabel('Validation Loss', fontsize=14, fontweight='bold')
ax.set_title('📉 Validation Error (Loss) - All Folds (NO AUGMENTATION)\nGhostNet K-Fold Cross Validation (7 Folds, 10 Epochs)',
             fontsize=16, fontweight='bold', pad=20)
ax.legend(loc='upper right', frameon=True, shadow=True, fontsize=10)
ax.grid(True, alpha=0.3)

# Add final value annotation
final_val_loss = avg_val_loss[-1]
ax.annotate(f'Final Avg: {final_val_loss:.4f}',
            xy=(10, final_val_loss), xytext=(8.5, final_val_loss + 0.3),
            arrowprops=dict(arrowstyle='->', color='red', lw=2),
            fontsize=12, fontweight='bold', color='red',
            bbox=dict(boxstyle='round,pad=0.5', facecolor='yellow', alpha=0.7))

plt.tight_layout()
plt.savefig('validation_error_curves_noaug.png', dpi=300, bbox_inches='tight')
plt.show()

print(f"✅ Final Average Validation Loss: {final_val_loss:.4f}")
print(f"📉 Loss Reduction: {avg_val_loss[0]:.4f} → {final_val_loss:.4f} ({(1 - final_val_loss/avg_val_loss[0])*100:.2f}% reduction)")

# ============================================================
# 2. TRAIN VS TEST ACCURACY - PER FOLD
# ============================================================

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 7))

# Prepare data
folds = [f'Fold {i}' for i in range(1, 8)]
train_acc_final = [training_data[f'fold{i}']['train_acc'][-1] for i in range(1, 8)]
test_acc = [training_data[f'fold{i}']['test_acc'] for i in range(1, 8)]
gaps = [train_acc_final[i] - test_acc[i] for i in range(7)]

# Bar chart comparison
x = np.arange(len(folds))
width = 0.35

bars1 = ax1.bar(x - width/2, train_acc_final, width, label='Train Acc (Epoch 10)',
                color=sns.color_palette("Greens", 3)[2], edgecolor='black', linewidth=1.5)
bars2 = ax1.bar(x + width/2, test_acc, width, label='Test Acc',
                color=sns.color_palette("Blues", 3)[2], edgecolor='black', linewidth=1.5)

ax1.set_xlabel('Fold', fontsize=14, fontweight='bold')
ax1.set_ylabel('Accuracy (%)', fontsize=14, fontweight='bold')
ax1.set_title('⚖️ Train vs Test Accuracy - Per Fold (NO AUGMENTATION)', fontsize=16, fontweight='bold', pad=15)
ax1.set_xticks(x)
ax1.set_xticklabels(folds)
ax1.legend(frameon=True, shadow=True, fontsize=12)
ax1.set_ylim([80, 102])
ax1.grid(axis='y', alpha=0.3)

# Add value labels on bars
for bars in [bars1, bars2]:
    for bar in bars:
        height = bar.get_height()
        ax1.text(bar.get_x() + bar.get_width()/2., height,
                f'{height:.2f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

# Overfitting gap scatter plot
ax2.scatter(range(1, 8), gaps, s=200, c=gaps, cmap='YlOrRd',
           edgecolors='black', linewidth=2, alpha=0.8)
ax2.plot(range(1, 8), gaps, linestyle='--', color='gray', alpha=0.5, linewidth=2)

# Add horizontal line for average gap
avg_gap = np.mean(gaps)
ax2.axhline(y=avg_gap, color='red', linestyle='--', linewidth=2.5,
           label=f'Avg Gap: {avg_gap:.2f}%')

ax2.set_xlabel('Fold Number', fontsize=14, fontweight='bold')
ax2.set_ylabel('Train-Test Gap (%)', fontsize=14, fontweight='bold')
ax2.set_title('🎯 Overfitting Gap Analysis (NO AUGMENTATION)', fontsize=16, fontweight='bold', pad=15)
ax2.set_xticks(range(1, 8))
ax2.legend(frameon=True, shadow=True, fontsize=12)
ax2.grid(True, alpha=0.3)

# Add colorbar
cbar = plt.colorbar(ax2.collections[0], ax=ax2)
cbar.set_label('Gap Magnitude', rotation=270, labelpad=20, fontweight='bold')

plt.tight_layout()
plt.savefig('train_vs_test_accuracy_noaug.png', dpi=300, bbox_inches='tight')
plt.show()

print(f"\n✅ Average Train Accuracy (Final): {np.mean(train_acc_final):.2f}%")
print(f"✅ Average Test Accuracy: {np.mean(test_acc):.2f}%")
print(f"⚠️  Average Overfitting Gap: {avg_gap:.2f}%")

# ============================================================
# 3. AVERAGE TRAIN VS VAL LOSS
# ============================================================

fig, ax = plt.subplots(figsize=(14, 8))

# Calculate averages
avg_train_loss = [np.mean([training_data[f'fold{i}']['train_loss'][e-1] for i in range(1, 8)])
                  for e in epochs]
avg_val_loss = [np.mean([training_data[f'fold{i}']['val_loss'][e-1] for i in range(1, 8)])
                for e in epochs]

# Plot
ax.plot(epochs, avg_train_loss, marker='o', linewidth=3,
        label='Train Loss', color=sns.color_palette("Greens", 3)[2], markersize=10)
ax.plot(epochs, avg_val_loss, marker='s', linewidth=3,
        label='Validation Loss', color=sns.color_palette("Reds", 3)[2], markersize=10)

# Fill between
ax.fill_between(epochs, avg_train_loss, avg_val_loss,
                alpha=0.2, color='orange', label='Gap')

ax.set_xlabel('Epoch', fontsize=14, fontweight='bold')
ax.set_ylabel('Loss', fontsize=14, fontweight='bold')
ax.set_title('📊 Average Train vs Validation Loss (NO AUGMENTATION)\nGhostNet-100 K-Fold Cross Validation (7 Folds, 10 Epochs)',
             fontsize=16, fontweight='bold', pad=20)
ax.legend(loc='upper right', frameon=True, shadow=True, fontsize=12)
ax.grid(True, alpha=0.3)

# Add annotations
ax.annotate(f'Start: {avg_train_loss[0]:.4f}',
            xy=(1, avg_train_loss[0]), xytext=(2, avg_train_loss[0] + 0.5),
            arrowprops=dict(arrowstyle='->', color='green', lw=2),
            fontsize=11, fontweight='bold', color='green')

ax.annotate(f'End: {avg_train_loss[-1]:.4f}',
            xy=(10, avg_train_loss[-1]), xytext=(8, avg_train_loss[-1] + 0.3),
            arrowprops=dict(arrowstyle='->', color='green', lw=2),
            fontsize=11, fontweight='bold', color='green')

plt.tight_layout()
plt.savefig('loss_comparison_noaug.png', dpi=300, bbox_inches='tight')
plt.show()

print(f"\n✅ Train Loss: {avg_train_loss[0]:.4f} → {avg_train_loss[-1]:.4f} ({(1 - avg_train_loss[-1]/avg_train_loss[0])*100:.2f}% reduction)")
print(f"✅ Val Loss: {avg_val_loss[0]:.4f} → {avg_val_loss[-1]:.4f} ({(1 - avg_val_loss[-1]/avg_val_loss[0])*100:.2f}% reduction)")

# ============================================================
# 4. AVERAGE TRAIN VS VAL ACCURACY
# ============================================================

fig, ax = plt.subplots(figsize=(14, 8))

# Calculate averages
avg_train_acc = [np.mean([training_data[f'fold{i}']['train_acc'][e-1] for i in range(1, 8)])
                 for e in epochs]
avg_val_acc = [np.mean([training_data[f'fold{i}']['val_acc'][e-1] for i in range(1, 8)])
               for e in epochs]

# Plot
ax.plot(epochs, avg_train_acc, marker='o', linewidth=3,
        label='Train Accuracy', color=sns.color_palette("Greens", 3)[2], markersize=10)
ax.plot(epochs, avg_val_acc, marker='s', linewidth=3,
        label='Validation Accuracy', color=sns.color_palette("Blues", 3)[2], markersize=10)

# Fill between
ax.fill_between(epochs, avg_train_acc, avg_val_acc,
                alpha=0.2, color='orange', label='Gap')

ax.set_xlabel('Epoch', fontsize=14, fontweight='bold')
ax.set_ylabel('Accuracy (%)', fontsize=14, fontweight='bold')
ax.set_title('📈 Average Train vs Validation Accuracy (NO AUGMENTATION)\nGhostNet K-Fold Cross Validation (7 Folds, 10 Epochs)',
             fontsize=16, fontweight='bold', pad=20)
ax.legend(loc='lower right', frameon=True, shadow=True, fontsize=12)
ax.set_ylim([0, 105])
ax.grid(True, alpha=0.3)

# Add annotations
ax.annotate(f'Final Train: {avg_train_acc[-1]:.2f}%',
            xy=(10, avg_train_acc[-1]), xytext=(7, avg_train_acc[-1] - 8),
            arrowprops=dict(arrowstyle='->', color='green', lw=2),
            fontsize=11, fontweight='bold', color='green',
            bbox=dict(boxstyle='round,pad=0.5', facecolor='lightgreen', alpha=0.7))

ax.annotate(f'Final Val: {avg_val_acc[-1]:.2f}%',
            xy=(10, avg_val_acc[-1]), xytext=(7, avg_val_acc[-1] + 3),
            arrowprops=dict(arrowstyle='->', color='blue', lw=2),
            fontsize=11, fontweight='bold', color='blue',
            bbox=dict(boxstyle='round,pad=0.5', facecolor='lightblue', alpha=0.7))

plt.tight_layout()
plt.savefig('accuracy_comparison_noaug.png', dpi=300, bbox_inches='tight')
plt.show()

print(f"\n✅ Final Train Accuracy: {avg_train_acc[-1]:.2f}%")
print(f"✅ Final Validation Accuracy: {avg_val_acc[-1]:.2f}%")
print(f"⚠️  Train-Val Gap: {avg_train_acc[-1] - avg_val_acc[-1]:.2f}%")

# ============================================================
# 5. SUMMARY HEATMAP
# ============================================================

fig, ax = plt.subplots(figsize=(12, 9))

# Prepare summary data
summary_data = []
for i in range(1, 8):
    fold_data = training_data[f'fold{i}']
    summary_data.append([
        fold_data['train_acc'][-1],  # Final train acc
        fold_data['val_acc'][-1],    # Final val acc
        fold_data['test_acc'],       # Test acc
        fold_data['train_loss'][-1], # Final train loss
        fold_data['val_loss'][-1],   # Final val loss
    ])

summary_df = pd.DataFrame(summary_data,
                          columns=['Train Acc', 'Val Acc', 'Test Acc', 'Train Loss', 'Val Loss'],
                          index=[f'Fold {i}' for i in range(1, 8)])

# Add average row
avg_row = summary_df.mean()
summary_df.loc['AVERAGE'] = avg_row

# Create heatmap
sns.heatmap(summary_df, annot=True, fmt='.2f', cmap='RdYlGn',
            linewidths=2, linecolor='black', cbar_kws={'label': 'Value'},
            vmin=0, vmax=100, ax=ax)

ax.set_title('📊 Summary Heatmap - All Metrics by Fold (NO AUGMENTATION)\nGhostNet-100 K-Fold Results (7 Folds, 10 Epochs)',
             fontsize=16, fontweight='bold', pad=20)
ax.set_xlabel('Metrics', fontsize=13, fontweight='bold')
ax.set_ylabel('Fold', fontsize=13, fontweight='bold')

plt.tight_layout()
plt.savefig('summary_heatmap_noaug.png', dpi=300, bbox_inches='tight')
plt.show()

print("\n" + "="*60)
print("📊 SUMMARY STATISTICS (NO AUGMENTATION - 7 FOLDS, 10 EPOCHS)")
print("="*60)
print(summary_df.round(2))
print("\n✅ All visualizations saved successfully!")
print("   • validation_error_curves_noaug.png")
print("   • train_vs_test_accuracy_noaug.png")
print("   • loss_comparison_noaug.png")
print("   • accuracy_comparison_noaug.png")
print("   • summary_heatmap_noaug.png")
# Out:
# /tmp/ipython-input-3543908782.py:110: UserWarning: Glyph 128201 (\N{CHART WITH DOWNWARDS TREND}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3543908782.py:111: UserWarning: Glyph 128201 (\N{CHART WITH DOWNWARDS TREND}) missing from font(s) DejaVu Sans.
#   plt.savefig('validation_error_curves_noaug.png', dpi=300, bbox_inches='tight')
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128201 (\N{CHART WITH DOWNWARDS TREND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ✅ Final Average Validation Loss: 0.1089
# 📉 Loss Reduction: 3.2742 → 0.1089 (96.67% reduction)
# /tmp/ipython-input-3543908782.py:175: UserWarning: Glyph 127919 (\N{DIRECT HIT}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3543908782.py:176: UserWarning: Glyph 127919 (\N{DIRECT HIT}) missing from font(s) DejaVu Sans.
#   plt.savefig('train_vs_test_accuracy_noaug.png', dpi=300, bbox_inches='tight')
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127919 (\N{DIRECT HIT}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ✅ Average Train Accuracy (Final): 99.89%
# ✅ Average Test Accuracy: 85.50%
# ⚠️  Average Overfitting Gap: 14.38%
# /tmp/ipython-input-3543908782.py:223: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3543908782.py:224: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.savefig('loss_comparison_noaug.png', dpi=300, bbox_inches='tight')
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ✅ Train Loss: 4.0395 → 0.0242 (99.40% reduction)
# ✅ Val Loss: 3.2742 → 0.1089 (96.67% reduction)
# /tmp/ipython-input-3543908782.py:273: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3543908782.py:274: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   plt.savefig('accuracy_comparison_noaug.png', dpi=300, bbox_inches='tight')
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ✅ Final Train Accuracy: 99.89%
# ✅ Final Validation Accuracy: 97.24%
# ⚠️  Train-Val Gap: 2.65%
# /tmp/ipython-input-3543908782.py:317: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3543908782.py:318: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.savefig('summary_heatmap_noaug.png', dpi=300, bbox_inches='tight')
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ============================================================
# 📊 SUMMARY STATISTICS (NO AUGMENTATION - 7 FOLDS, 10 EPOCHS)
# ============================================================
#          Train Acc  Val Acc  Test Acc  Train Loss  Val Loss
# Fold 1       99.92    98.81     85.47        0.02      0.08
# Fold 2       99.88    97.86     85.51        0.02      0.08
# Fold 3      100.00    97.14     86.20        0.02      0.12
# Fold 4       99.84    97.14     84.95        0.02      0.10
# Fold 5       99.92    95.94     85.51        0.02      0.14
# Fold 6       99.80    97.37     85.92        0.02      0.12
# Fold 7       99.84    96.42     84.95        0.03      0.12
# AVERAGE      99.89    97.24     85.50        0.02      0.11
#
# ✅ All visualizations saved successfully!
#    • validation_error_curves_noaug.png
#    • train_vs_test_accuracy_noaug.png
#    • loss_comparison_noaug.png
#    • accuracy_comparison_noaug.png
#    • summary_heatmap_noaug.png
